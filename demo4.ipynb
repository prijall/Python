# %%
List= ["prijal", 2, 3.4, "hello"]
print(List)
# Out:
# ['prijal', 2, 3.4, 'hello']

# %%
print(List[2])
print(List[:2])
# Out:
# 3.4
# ['prijal', 2]

# %%
dict={'Name':['prijal', 'aayush', 'aarogya'],
      'rollno':[12,3,4], 'address':['lalitpur', 'kathmandu', 'bhaktapur']}

print(dict['Name'])
print(dict.get('address'))
# Out:
# ['prijal', 'aayush', 'aarogya']
# ['lalitpur', 'kathmandu', 'bhaktapur']

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x= np.linspace(0, 10, 1000)
# Out:
# array([ 0.        ,  0.01001001,  0.02002002,  0.03003003,  0.04004004,
#         0.05005005,  0.06006006,  0.07007007,  0.08008008,  0.09009009,
#         0.1001001 ,  0.11011011,  0.12012012,  0.13013013,  0.14014014,
#         0.15015015,  0.16016016,  0.17017017,  0.18018018,  0.19019019,
#         0.2002002 ,  0.21021021,  0.22022022,  0.23023023,  0.24024024,
#         0.25025025,  0.26026026,  0.27027027,  0.28028028,  0.29029029,
#         0.3003003 ,  0.31031031,  0.32032032,  0.33033033,  0.34034034,
#         0.35035035,  0.36036036,  0.37037037,  0.38038038,  0.39039039,
#         0.4004004 ,  0.41041041,  0.42042042,  0.43043043,  0.44044044,
#         0.45045045,  0.46046046,  0.47047047,  0.48048048,  0.49049049,
#         0.5005005 ,  0.51051051,  0.52052052,  0.53053053,  0.54054054,
#         0.55055055,  0.56056056,  0.57057057,  0.58058058,  0.59059059,
#         0.6006006 ,  0.61061061,  0.62062062,  0.63063063,  0.64064064,
# ...

# %%
y=np.cos(x);
plt.plot(x, y);

# %%
plt.scatter(x[:30],y[:30], color='green')

# %%
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
df = pd.read_csv('C:/Users/khadk/Desktop/data/country_wise_latest.csv')

# %%
df.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
df = pd.read_csv('C:/Users/khadk/Desktop/data/country_wise_latest.csv')
df.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
df2= df.groupby('Country/Region')[['Country/Region', 'Confirmed', 'Deaths']].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26224\3205825575.py in ?()
# ----> 1 df2= df.groupby('Country/Region')[['Country/Region', 'Confirmed', 'Deaths']].sum().reset_index()
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6216                     level_values = algorithms.take(
#    6217                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6218                     )
#    6219
# -> 6220                 new_obj.insert(
#    6221                     0,
#    6222                     name,
#    6223                     level_values,
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# a figure with one axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
np.random.seed(10)  # Setting the seed to 10
random_array = np.random.rand(5)  # Generating a random array of 5 elements
print(random_array)
# Out:
# [0.77132064 0.02075195 0.63364823 0.74880388 0.49850701]

# %%
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
x= pd.read_csv('C:/Users/khadk/Desktop/data/country_wise_latest.csv')
x
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
x.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
def number(x):
    if x<1:
        return -1
    
    elif x>1:
        return 1
    
    else:
        return 0
    


number(2)
# Out:
# 1
